# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

visa_dataset="/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/Visadataset.csv"
visa_df=pd.read_csv(visa_dataset)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
Categorical Vs Catergorical

Continent Vs CaseStatus

# %%
cols=['prevailing_wage','case_status']
visa_df.loc(cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_5/f439c61s71nc6hfdz2f2ndtr0000gn/T/ipykernel_49107/3777041563.py in ?()
#       1 cols=['prevailing_wage','case_status']
# ----> 2 visa_df.loc(cols)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, axis)
#     675         # we need to return a copy of ourselves
#     676         new_self = type(self)(self.name, self.obj)
#     677
#     678         if axis is not None:
# --> 679             axis_int_none = self.obj._get_axis_number(axis)
#     680         else:
#     681             axis_int_none = axis
#     682         new_self.axis = axis_int_none
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(cls, axis)
#     510     @classmethod
#     511     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     512         try:
# ...

# %%
visa_df[(visa_df['continent']=="Asia")&(visa_df['case_status']=="Certified")]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
Cross tab

# %%
col1=visa_df['continent']
col2=[visa_df['case_status'],visa_df['education_of_employee']]
result1=pd.crosstab(col1,col2)
result1
# Out:
# case_status            Certified                                    Denied  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# continent
# Africa                        81        43          23      250         62
# Asia                        4407       780         676     5149       2761
# Europe                      1040       788         162      967        259
# North America                641       207         210      979        584
# Oceania                       38        19          19       46         28
# South America                160        75          74      184        173
#
# case_status
# education_of_employee Doctorate High School Master's
# continent
# Africa                       11          43       38
# Asia                        143        1614     1331
# Europe                       58         328      130
# North America                51         191      429
# Oceania                       3          17       22
# ...

# %%
col1=visa_df['case_status']
col2=[visa_df['continent'],visa_df['education_of_employee']]
result2=pd.crosstab(col1,col2)

# %%
result1.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='case_status'>

# %%
Numerical Vs Numerical

# %% [markdown]
# $ Scatter $ $ Plots $
#
#     -plt.scatter
#
#     - Two variables x and y axis
#
#     - Both variables should be numerical
#
#     - It provides relationship b/w the variables
#
#         - + vely related
#
#         - - vely related
#
#         - no relation

# %%
x=[1,2,3,4,5]
y=[11,12,13,14,15]
plt.scatter(x,y)
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in range(-4,5)]
plt.scatter(x,y)
plt.plot(x,y)

# %%
x=visa_df['prevailing_wage']
y=visa_df['no_of_employees']
plt.scatter(x,y)

# %% [markdown]
# Correlation-Coefiecient
#     - Denoted with r
#     - Pearson correlation coefficient
#     - r varies from -1 to 1
#     - r= -1 to 0 : Negatively correlated
#     - r= 0 to 1: Postively Correlated
#     - r=0 : No relation

# %%
r= (Cov(x,y)/Sd(x)*Sd(y))

# %%
x=visa_df['prevailing_wage']
y=visa_df['yr_of_estab']
plt.scatter(x,y)

# %%
wine_dataset="/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/winequality_red.csv"
wine_df=pd.read_csv(wine_dataset)
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
As it is difficult to analyse by above we use heat map

# %%
# sns heatmap(covv coeff)
# available from seaborn package
#line on the right side of map represent min=0,max=1
#entire matrix value ranges from 0 to 1

# %%
corr=visa_df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
wine_dataset="/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/winequality_red.csv"
wine_df=pd.read_csv(wine_dataset)
corr_w=wine_df.corr(numeric_only=True)
sns.heatmap(corr_w,annot=True)
# Out:
# <Axes: >

# %%
x=wine_df['fixed acidity']
y=wine_df['citric acid']
plt.scatter(x,y) # +ve relation

# %%
x=wine_df['fixed acidity']
y=wine_df['pH']
plt.scatter(x,y) # -ve relation

# %% [markdown]
# EDA-Session1
#     - We just read the data
#     - How to create data frames using list and dict
#     - How to add new column
#     - How to add new rows
#     - How to drop columns and rows
#     - How to change the index
#     - How to save the data frame local
# EDA-Session2:
#     - We read the data
#     - shape,size,len,head,tail
#     - columns,dtypes,info
#     - Seperated Cat and num columns
# EDA-Session3: Categorical column analysis
#     - We read one categorical column
#     - Unique and nunique
#     - Value counts
#     - Frequency table
#     - bar plot and Pie chart
# EDA-Session4: Numerical column analysis
#     - We read one Numerical column
#     - We calculate all statistical measurements
#     - Mean
#     - Median
#     - count
#     - std
#     - max min
#     - 25p 50p 75p
#     - Histogram
#     - Distribution plots
#     - Box plot for outliers
# EDA-Session5: Outlier analysis
#     - We read one Numerical column
#     - We plot the boxlot
#     - Perform the outlier analysis
#     - Impute the outliers using medain value
#     - np.where
#     - EDA-Session6: Bi variate and Multi variate analysis
#     - Categorical vs Categorical
#     - pd.cross tab
#     - plot the results
#     - Numerical vs Numerical
#     - Relation ship between variables
#     - Scatter plot
#     - Correlation
#     - heatmap

# %% [markdown]
# `
