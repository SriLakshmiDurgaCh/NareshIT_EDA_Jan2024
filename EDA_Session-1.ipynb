# %%
###### Exploratory Data Analysis#########

1.Pandas-- Data frame Analysis
2.Numpy--Number Python math package
3.Matplotlib---plotting/graphs/visualisation
4.Seaborn---plotting
5.plotly---plotting
6.Bokhe--plotting
`

######## Machine Learning ##########

7.Scikit-learn   --- ML models will be available , imporatant for ML
8.Stats ----Statistical Models

######## Deep Learning #######

9.Tensor Flow    -- Devaloped by Google
10.Keras
11.Torch Frmwrk
12.Open CV -- Computer Vision - Image Analysis   Sentdex -- youtube videos

###### NLP ########

13.NLTK ---- Natural language Tool kit
14.Scipy ---- 

##### GenAI (LLM) ####
###Prompt Engineering###

15.ChatGPT is developed by openAI + Azure
16.MakerSuite developed by Google
17.Gemini developed by Google

##### Company Based 

18.HuggingFace

    Transformers BERT models
    DL LLP NLP  ML all tasks it will do

19.Alllen LLP


########## Spl Packages ##########

1. Random
2. Time
3. Math 
4. API      Flask
5. UI Apps  Streamlit

# %%
Order of Learning

Data Analysis
ML
DL
NLP
BERT : Transformers : T GPT
LLP : Gen AI

# %%
import matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_dataset="/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/Visadataset.csv"
#file=open(visa_dataset)
#file.read()
pd.read_csv(visa_dataset)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# !pip install matplotlib Command to install a package

# %%
bank_data="/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/bank.csv"
pd.read_csv(bank_data,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
Create data frame using list

# %%
Create data frame using list

# %%
Names=['Ramesh','Suresh','Satish']
Age=[25,30,35]
pd.DataFrame(zip(Names,Age))
# Out:
#         0   1
# 0  Ramesh  25
# 1  Suresh  30
# 2  Satish  35

# %%
Names=['Ramesh','Suresh','Satish']
Age=[25,30,35]
pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=['A','B','C'])
# Out:
#      Name  Age
# A  Ramesh   25
# B  Suresh   30
# C  Satish   35

# %%
Names=['Ramesh','Suresh','Satish']
Age=[25,30,35]
df1=pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=['A','B','C']) # variable df1 for data frame
df1['City']=['Hyd','Banglore','Chn']
df1
# Out:
#      Name  Age      City
# A  Ramesh   25       Hyd
# B  Suresh   30  Banglore
# C  Satish   35       Chn

# %%
df1.index=[0,1,2]
df1
# Out:
#      Name  Age      City
# 0  Ramesh   25       Hyd
# 1  Suresh   30  Banglore
# 2  Satish   35       Chn

# %%
len(df1.index)
# Out:
# 3

# %%
df1.loc(3)=['Hari',20,'Vja']
# Out:
#   Cell In[23], line 1
#     df1.loc(2)=['Hari',20,'Vja']
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
Write to file

# %%
df1.to_csv("/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/output.csv",index=False)
pd.read_csv("/Users/srilakshmidurgachunduri/Documents/NareshIT/Data Science/EDA/Data Files/output.csv")
# Out:
#      Name  Age      City
# 0  Ramesh   25       Hyd
# 1  Suresh   30  Banglore
# 2  Satish   35       Chn

# %%
d1={'Names':['Ramesh','Suresh','Satish'],'Age':[12,23,34]}
pd.DataFrame(d1)
# Out:
#     Names  Age
# 0  Ramesh   12
# 1  Suresh   23
# 2  Satish   34

# %%
#Creation od Empty Dataframe
df2=pd.DataFrame()

# %%
df2['Even']=[2,4,6,8]
df2['Odd']=[1,3,5,7]
df2
# Out:
#    Even  Odd
# 0     2    1
# 1     4    3
# 2     6    5
# 3     8    7

# %%
import random
even_list=[]
odd_list=[]
for i in range(0,10):
    num=random.randint(20,50)
    if(num%2==0):
        even_list.append(num)
    else:
        odd_list.append(num)
print(even_list)
print(odd_list)
# Out:
# [38, 26, 46, 44, 20, 36]
# [39, 33, 41, 49]

# %%
df3=pd.DataFrame(zip(even_list,odd_list),columns=[ 'Even','Odd'])
df3
# Out:
#    Even  Odd
# 0    38   39
# 1    26   33
# 2    46   41
# 3    44   49
